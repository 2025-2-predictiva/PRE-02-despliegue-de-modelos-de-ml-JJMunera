# %%
import pandas as pd  #  type: ignore

df = pd.read_csv("../files/input/house_data.csv")

features = df[
    [
        "bedrooms",
        "bathrooms",
        "sqft_living",
        "sqft_lot",
        "floors",
        "waterfront",
        "condition",
    ]
]

target = df[["price"]]

target
# Out:
#           price
# 0      221900.0
# 1      538000.0
# 2      180000.0
# 3      604000.0
# 4      510000.0
# ...         ...
# 21608  360000.0
# 21609  400000.0
# 21610  402101.0
# 21611  400000.0
# 21612  325000.0
#
# [21613 rows x 1 columns]

# %%
features.bathrooms.value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='bathrooms'>

# %%
target.plot(kind="hist", edgecolor="black", bins=10)
# Out:
# <Axes: ylabel='Frequency'>
